# %% [markdown]
# # Playground

# %% [markdown]
# This notebook was used to play around with different thresholds to find the perfect combination

# %%
import process
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import numpy as np

# %%
mtx, dist = process.calculate_camera_distortion()
M_persp, Minv_persp = process.get_perspective_transform_matrixes()

# %%
img1 = cv2.imread("test_images/test1.jpg")
img2 = cv2.imread("test_images/test2.jpg")
img3 = cv2.imread("test_images/test3.jpg")
img4 = cv2.imread("test_images/test4.jpg")
img5 = cv2.imread("test_images/test5.jpg")
img6 = cv2.imread("test_images/test6.jpg")
#img_undist = cv2.undistort(img, mtx, dist, None, mtx)
#img_processed = process.process_image(img, mtx, dist, M_persp, Minv_persp)
h_thresh=(18, 255)
s_thresh=(0, 80)
v_thresh=(180, 255)
img_pro1 = process.white_lines(img1, h_thresh, s_thresh, v_thresh)
img_pro2 = process.white_lines(img2, h_thresh, s_thresh, v_thresh)
img_pro3 = process.white_lines(img3, h_thresh, s_thresh, v_thresh)
img_pro4 = process.white_lines(img4, h_thresh, s_thresh, v_thresh)
img_pro5 = process.white_lines(img5, h_thresh, s_thresh, v_thresh)
img_pro6 = process.white_lines(img6, h_thresh, s_thresh, v_thresh)

plt.figure(figsize=(30,20))

plt.subplot(6,2,1)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,2)
plt.title('Filtered')
fig =plt.imshow(img_pro1)

plt.subplot(6,2,3)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,4)
plt.title('Filtered')
fig =plt.imshow(img_pro2)

plt.subplot(6,2,5)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,6)
plt.title('Filtered')
fig =plt.imshow(img_pro3)

plt.subplot(6,2,7)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,8)
plt.title('Filtered')
fig =plt.imshow(img_pro4)

plt.subplot(6,2,9)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img5, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,10)
plt.title('Filtered')
fig =plt.imshow(img_pro5)

plt.subplot(6,2,11)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img6, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,12)
plt.title('Filtered')
fig =plt.imshow(img_pro6)

# %%
#img1 = cv2.imread("test_images/test1.jpg")
img1 = VideoFileClip("project_video.mp4").get_frame(1.0)
img2 = cv2.imread("test_images/test2.jpg")
img3 = cv2.imread("test_images/test3.jpg")
img4 = cv2.imread("test_images/test4.jpg")
img5 = cv2.imread("test_images/test5.jpg")
img6 = cv2.imread("test_images/test6.jpg")
#img_undist = cv2.undistort(img, mtx, dist, None, mtx)
#img_processed = process.process_image(img, mtx, dist, M_persp, Minv_persp)
h_thresh=(0, 50)
s_thresh=(100, 255)
v_thresh=(100, 255)
img_pro1 = process.yellow_lines(img1, h_thresh, s_thresh, v_thresh)
img_pro2 = process.yellow_lines(img2, h_thresh, s_thresh, v_thresh)
img_pro3 = process.yellow_lines(img3, h_thresh, s_thresh, v_thresh)
img_pro4 = process.yellow_lines(img4, h_thresh, s_thresh, v_thresh)
img_pro5 = process.yellow_lines(img5, h_thresh, s_thresh, v_thresh)
img_pro6 = process.yellow_lines(img6, h_thresh, s_thresh, v_thresh)

plt.figure(figsize=(30,20))

plt.subplot(6,2,1)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,2)
plt.title('Filtered')
fig =plt.imshow(img_pro1)

plt.subplot(6,2,3)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,4)
plt.title('Filtered')
fig =plt.imshow(img_pro2)

plt.subplot(6,2,5)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,6)
plt.title('Filtered')
fig =plt.imshow(img_pro3)

plt.subplot(6,2,7)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,8)
plt.title('Filtered')
fig =plt.imshow(img_pro4)

plt.subplot(6,2,9)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img5, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,10)
plt.title('Filtered')
fig =plt.imshow(img_pro5)

plt.subplot(6,2,11)
plt.title('Original image')
fig = plt.imshow(cv2.cvtColor(img6, cv2.COLOR_BGR2RGB))

plt.subplot(6,2,12)
plt.title('Filtered')
fig =plt.imshow(img_pro6)

# %%
#binary image
def color_mask(color_space,low,high):
    mask = cv2.inRange(color_space, low, high)
    return mask

# %%
from IPython.html import widgets
import ipywidgets

#image = cv2.imread("test_images/test1.jpg")
image = VideoFileClip("project_video.mp4").get_frame(23)

img_size=(image.shape[1],image.shape[0])
image_HSV = cv2.cvtColor(image,cv2.COLOR_RGB2HSV)

@widgets.interact(w_h_l = widgets.IntSlider(min=0,max=255,step=1,value=0),
                                w_h_h = widgets.IntSlider(min=0,max=255,step=1,value=255),
                                  w_s_l = widgets.IntSlider(min=0,max=255,step=1,value=0),
                                  w_s_h = widgets.IntSlider(min=0,max=255,step=1,value=32),
                                  w_v_l = widgets.IntSlider(min=0,max=255,step=1,value=180),
                                  w_v_h = widgets.IntSlider(min=0,max=255,step=1,value=255))
def pipe_trial( w_h_l,w_h_h,w_s_l,w_s_h,w_v_l,w_v_h):
    h_thresh=(w_h_l, w_h_h)
    s_thresh=(w_s_l, w_s_h)
    v_thresh=(w_v_l, w_v_h)
    white_lane = process.yellow_lines(img1, h_thresh, s_thresh, v_thresh)

    f,(ax1,ax2) =plt.subplots(1,2,figsize=(24,9))
    ax1.imshow(image)
    ax2.imshow(white_lane,cmap="gray")

# %%
from moviepy.editor import VideoFileClip
img = VideoFileClip("project_video.mp4").get_frame(21.5)
#img = cv2.imread("output_images/test_video_23.jpg")
img_undist = cv2.undistort(img, mtx, dist, None, mtx)
#img_processed = process.process_image(img, mtx, dist, M_persp, Minv_persp)
#white
#h_thresh=(4, 255)
#s_thresh=(0, 35)
#v_thresh=(207, 255)
#img_processed = process.white_lines(img_undist, h_thresh, s_thresh, v_thresh)
img_processed = process.filter_pipeline_single_image(img_undist)

h_thresh=(18, 110)
s_thresh=(100, 255)
v_thresh=(100, 255)
#img_processed = process.yellow_lines(img_undist, h_thresh, s_thresh, v_thresh)
#img_processed = process.yellow_lines(img_undist)

img_size = (img.shape[1], img.shape[0])
img_warped = cv2.warpPerspective(img_processed, M_persp, img_size, flags=cv2.INTER_LINEAR)

#h_thresh=(0, 50)
#s_thresh=(100, 255)
#v_thresh=(100, 255)
#img_processed = process.yellow_lines(img_undist, h_thresh, s_thresh, v_thresh)
#img_processed = process.yellow_lines(img_undist)

plt.figure(figsize=(30,20))

#plt.subplot(6,2,1)
#plt.title('Original image')
#fig = plt.imshow(img)

plt.subplot(1,1,1)
plt.title('Filtered')
fig =plt.imshow(img_warped)
